# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import joblib
import os
from glob import glob
import shutil
from urllib.request import urlretrieve

# %%
print(os.getcwd())
os.chdir('/content/drive/MyDrive/aivle/big_proj/Hashtag-Generator-main/insta_crawling')
os.getcwd()
# Out:
# /content
# '/content/drive/MyDrive/aivle/big_proj/Hashtag-Generator-main/insta_crawling'

# %% [markdown]
# # 데이터프레임 가져오기

# %%
DIR = 'preprocessed/dataframe'
df = joblib.load(f'{DIR}/insta_df.pkl')
df
# Out:
#       검색키워드                                    이미지파일명  \
# 0     펫스타그램  af37feb6-2166-440a-9612-917e5bd32e99.jpg
# 1     펫스타그램  ac8fc4dc-8179-4808-b8d5-ee141f4432f5.jpg
# 2     펫스타그램  b5500161-a207-4213-801b-396f4d1ef3eb.jpg
# 3     펫스타그램  d1697f81-06a1-4a8a-a5fa-1a764b28066a.jpg
# 4     펫스타그램  5d6b1c34-0fda-4b69-8b52-157424878611.jpg
# ...     ...                                       ...
# 1791     집사  100fc2de-1947-4d6f-934e-9c1454d1fc3c.jpg
# 1792     집사  1e330d1d-332e-49d2-9f7b-83716e1009dc.jpg
# 1793     집사  d689c495-5547-4353-bb25-afd655b24e0b.jpg
# 1794     집사  fd30638c-ed60-4736-853e-7b82efd28dc8.jpg
# 1795     집사  c60f3645-61e2-4462-9a52-a955e0107ee7.jpg
#
#                                                    파일경로    좋아요  \
# 0     image/펫스타그램/af37feb6-2166-440a-9612-917e5bd32e...   2438
# 1     image/펫스타그램/ac8fc4dc-8179-4808-b8d5-ee141f4432...   2039
# 2     image/펫스타그램/b5500161-a207-4213-801b-396f4d1ef3...  50285
# 3     image/펫스타그램/d1697f81-06a1-4a8a-a5fa-1a764b2806...    136
# 4     image/펫스타그램/5d6b1c34-0fda-4b69-8b52-1574248786...  28508
# ...                                                 ...    ...
# 1791  image/집사/100fc2de-1947-4d6f-934e-9c1454d1fc3c.jpg     11
# 1792  image/집사/1e330d1d-332e-49d2-9f7b-83716e1009dc.jpg      9
# 1793  image/집사/d689c495-5547-4353-bb25-afd655b24e0b.jpg     17
# 1794  image/집사/fd30638c-ed60-4736-853e-7b82efd28dc8.jpg     17
# 1795  image/집사/c60f3645-61e2-4462-9a52-a955e0107ee7.jpg      0
#
#                                                    해시태그  이미지한개  \
# 0     [#pom, #멍스타그램, #pomeranian, #포메, #pet, #강아지모델,...  False
# 1     [#영화관, #동물스타그램, #반려견, #펫스타그램, #dog, #cat, #pet...  False
# 2     [#쁘띠아랑, #instadog, #팜므파탈백돼지걸, #반려견, #わんちゃん, #l...  False
# 3     [#멍팔환영, #instadog, #petstagram, #반려견소통, #l4l, ...  False
# 4     [#makji, #pet, #캣스타그램, #고양이일상, #kitten, #반려묘, ...  False
# ...                                                 ...    ...
# 1791  [#유치원, #petstagram, #소통, #도니벼리, #데일리, #👧, #😘, ...   True
# 1792  [#귀여운고양이, #korat, #catsofinstagram, #instacat,...   True
# 1793  [#디지털아트, #catsgallery, #drawing, #취미생활, #태비, #...   True
# 1794  [#고양이일상, #치즈, #catlife, #러시안블루, #랜선집사, #고양이, #...   True
# 1795  [#침대, #모나침대, #cat, #시몬스침대, #시몬스, #침대프레임, #작은, ...   True
#
#                                         게시글url  \
# 0     https://www.instagram.com/p/Ccg47zap-EJ/
# 1     https://www.instagram.com/p/CchvCi7phd3/
# 2     https://www.instagram.com/p/Ccfd5SOpL2W/
# 3     https://www.instagram.com/p/CcfPqzNJvRb/
# 4     https://www.instagram.com/p/CchmY14LZKL/
# ...                                        ...
# 1791  https://www.instagram.com/p/CclzJ5dB2JP/
# 1792  https://www.instagram.com/p/CclzCySrsJT/
# 1793  https://www.instagram.com/p/CclzGePP7nr/
# 1794  https://www.instagram.com/p/CclyIf6hGg_/
# 1795  https://www.instagram.com/p/CclxqX9vqym/
#
#                                                  이미지url
# 0     https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 1     https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 2     https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 3     https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 4     https://scontent-gmp1-1.cdninstagram.com/v/t51...
# ...                                                 ...
# 1791  https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 1792  https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 1793  https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 1794  https://scontent-gmp1-1.cdninstagram.com/v/t51...
# 1795  https://scontent-gmp1-1.cdninstagram.com/v/t51...
#
# [1796 rows x 8 columns]

# %% [markdown]
# # 저장경로 설정

# %%
DIR_SAVE = 'preprocessed/image'
try:
    os.makedirs(DIR_SAVE)
except OSError:
    print('이미 존재합니다')

# %% [markdown]
# # 불러올 경로 설정

# %%
DIR_LOAD = 'image'

# %% [markdown]
# # 이미지 옮겨심기

# %%
for keyword, file_name, img_url in zip(df['검색키워드'], df['이미지파일명'], df['이미지url']):
    try:
        load_file_path = f'{DIR_LOAD}/{keyword}/{file_name}'
        save_file_path = f'{DIR_SAVE}/'
        shutil.copy2(load_file_path, save_file_path)
    except Exception as ex:
        print('에러발생', ex)
        urlretrieve(img_url, f'{save_file_path}{file_name}')
