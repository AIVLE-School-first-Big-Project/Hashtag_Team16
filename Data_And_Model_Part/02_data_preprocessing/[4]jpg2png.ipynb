# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/aivle/big_proj/Hashtag-Generator-main/insta_crawling
# !ls
# Out:
# /content/drive/MyDrive/aivle/big_proj/Hashtag-Generator-main/insta_crawling
# '경용이형이 분리한 이미지 반영하는 주피터노트북 1회용.ipynb'
# '[2](WARNING-RESET)크롤링_데이터프레임_전처리.ipynb'
# '[2](WARNING-RESET)(local)크롤링_데이터프레임_전처리.ipynb'
# '[3](WARNING-RESET)데이터프레임에 존재하는 이미지만 따로 저장하기.ipynb'
# '[3](WARNING-RESET)(local)데이터프레임에 존재하는 이미지만 따로 저장하기.ipynb'
# '[4]jpg2png.ipynb'
# 'classification_modeling_파일불러오기 포함.ipynb'
# '깃 clone.ipynb'
#  data
#  Hashtag_Team16
#  image
# '데이터프레임 피클 불러오는법.ipynb'
# '전처리데이터 확인.ipynb'
#  jpg2png.py
#  preprocessed
#  preprocessing_step1.py
#  __pycache__
#  seped_image

# %%
# 코랩 프로만 가능
# !pip install kora
# from kora import console
# console.start()  # and click link

# %%
#bash쉘 실행시키고, 밑에 명령어 한 줄 씩 복붙하고 기다리면 끝.
# !bash
#cd /content/drive/MyDrive/aivle/big_proj/Hashtag-Generator-main/insta_crawling
#python jpg2png.py
# Out:
# Streaming output truncated to the last 5000 lines.
# 3426 a25eef1e-9332-4fda-b997-40f3409b7288.jpg
# 30 824bd024-f47a-4306-bdbd-a0f066021c80.jpg
# 1729 5904b560-6aaa-43fe-ba8a-6a07f6c479ff.jpg
# 31 af44488a-dac6-4c2e-a3ac-f2090eb2124b.jpg
# 3427 6b98ac01-deef-4dc2-8e20-ad65501284bd.jpg
# 1730 3d3c27e5-2a2e-4c12-9d12-17ad1fcf500b.jpg
# 32 11b159fd-4b52-4c23-9b7d-0c20194d834f.jpg
# 1731 c2ec3501-75ca-4e90-a730-e64fb9eba9b2.jpg
# 3428 5f99a9b8-7c54-4dec-a027-8d57ae669dcc.jpg
# 33 ee7f6913-1af6-4909-971f-3aa925eb42ba.jpg
# 1732 13181938-e92c-4761-abd7-351627654d59.jpg
# 3429 784a2ef3-5f5e-4f5f-a489-02addd9bb2de.jpg
# 34 e2676eeb-e25c-40a3-88d9-d1167430b511.jpg
# 1733 690be7af-0591-44f2-8ab5-58e18c0582fc.jpg
# 3430 9b04ae3a-634f-4ca3-8d03-17292817f9ac.jpg
# 35 34ec6338-644f-4dbf-8144-5a870c1b533e.jpg
# 1734 c4296723-6753-4c3f-9ea2-ebc3dadadf08.jpg
# 3431 980a0385-97dc-4dbc-846d-35d8eaf6ac54.jpg
# 36 1bc3eb74-e12c-4695-9a0f-77f4e2bd90b3.jpg
# 1735 79b78629-15f1-4494-8ab7-c6dfc527019b.jpg
# ...
