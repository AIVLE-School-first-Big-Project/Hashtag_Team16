# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import joblib
import os
from glob import glob

# %% [markdown]
# # 경로설정

# %%
ROOT_PATH = '/content/drive/MyDrive/aivle/big_proj/Hashtag-Generator-main/insta_crawling/'

DATAFRAME_FILENAME = 'insta_df.pkl'
DATAFRAME_PATH = f'{ROOT_PATH}preprocessed/dataframe/{DATAFRAME_FILENAME}'


UPDATE_DATAFRAME_FILENAME = 'update_df.pkl'
UPDATE_DATAFRAME_PATH = f'{ROOT_PATH}preprocessed/dataframe/{UPDATE_DATAFRAME_FILENAME}'

DEL_IMAGE_PATH = f'{ROOT_PATH}/seped_image/del_image'
CLEAN_IMAGE_PATH = f'{ROOT_PATH}/seped_image/clean_image'
AD_IMAGE_PATH = f'{ROOT_PATH}/seped_image/ad_image'

# %% [markdown]
# # update_df.pkl 생성

# %%
df = joblib.load(DATAFRAME_PATH)
# Out:
# 기존 데이터(update_df.pkl)를 불러옵니다.

# %% [markdown]
# # 파일 경로 가져오기

# %%
del_image_path__LS = os.listdir(DEL_IMAGE_PATH)
clean_image_path__LS = os.listdir(CLEAN_IMAGE_PATH)
ad_image_path__LS = os.listdir(AD_IMAGE_PATH)

# %%
print(len(del_image_path__LS))
print(len(clean_image_path__LS))
print(len(ad_image_path__LS))
# Out:
# 974
# 3646
# 519

# %% [markdown]
# # update_df.pkl에 반영. 데이터프레임에 반영

# %% [markdown]
# * 이거 나중에 이미지url 확인해서 같이 없애야함.

# %%
update_df
# Out:
#       검색키워드                                    이미지파일명  \
# 0     펫스타그램  af37feb6-2166-440a-9612-917e5bd32e99.jpg
# 1     펫스타그램  ac8fc4dc-8179-4808-b8d5-ee141f4432f5.jpg
# 2     펫스타그램  b5500161-a207-4213-801b-396f4d1ef3eb.jpg
# 3     펫스타그램  d1697f81-06a1-4a8a-a5fa-1a764b28066a.jpg
# 4     펫스타그램  5d6b1c34-0fda-4b69-8b52-157424878611.jpg
# ...     ...                                       ...
# 5087    도치맘  3f53c840-bab2-4047-ae8a-fe73f630ea9a.jpg
# 5088    도치맘  f3628946-e032-46db-ad32-57d9e102ff09.jpg
# 5089    도치맘  a8293498-4a5e-4905-bc45-15b65fbc78e2.jpg
# 5090    도치맘  ad201b9a-81f1-4b87-b87e-e703533653e2.jpg
# 5091    도치맘  da52680b-0141-443d-802c-c72a06eb47b8.jpg
#
#                                                    파일경로    좋아요  \
# 0     image/펫스타그램/af37feb6-2166-440a-9612-917e5bd32e...   2438
# 1     image/펫스타그램/ac8fc4dc-8179-4808-b8d5-ee141f4432...   2039
# 2     image/펫스타그램/b5500161-a207-4213-801b-396f4d1ef3...  50285
# ...

# %%
update_df['이미지파일명'].isin(del_image_path__LS).sum()
# Out:
# 560

# %%
for i in range(len(update_df)):
    if update_df.loc[i, '이미지파일명'] in del_image_path__LS:
        update_df.loc[i, '삭제여부'] = True
    if update_df.loc[i, '이미지파일명'] in ad_image_path__LS:
        update_df.loc[i, '광고여부'] = True

# %%
joblib.dump(update_df, UPDATE_DATAFRAME_PATH)
# Out:
# ['/content/drive/MyDrive/aivle/big_proj/Hashtag-Generator-main/insta_crawling/preprocessed/dataframe/update_df.pkl']
